# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding ='utf-8',encoding_errors='replace')

# %% [markdown]
# # Assistant
# This error occurs because the CSV file contains characters that are not encoded in UTF-8 format, but pandas is trying to read it using UTF-8 encoding by default. When it encounters bytes that don't form valid UTF-8 sequences, it raises a UnicodeDecodeError.
#
# The error happens when pandas tries to decode the file at a specific byte position (606-607) and finds characters that don't match the expected UTF-8 encoding pattern.
#
# Would you like me to provide the corrected code?

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 3693  ham  Ok im not sure what time i finish tomorrow but...        NaN
# 3971  ham                                      WOT U UP 2 J?        NaN
# 605   ham                          TaKe CaRE n gET WeLL sOOn        NaN
# 242   ham  Okay. No no, just shining on. That was meant t...        NaN
# 3791  ham  Love it! I want to flood that pretty pussy wit...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3693        NaN        NaN
# 3971        NaN        NaN
# 605         NaN        NaN
# 242         NaN        NaN
# 3791        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# #1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   str
#  1   v2          5572 non-null   str
#  2   Unnamed: 2  50 non-null     str
#  3   Unnamed: 3  12 non-null     str
#  4   Unnamed: 4  6 non-null      str
# dtypes: str(5)
# memory usage: 677.2 KB

# %%
#drop last 3 colums
df= df.drop(columns = ['Unnamed: 2','Unnamed: 3','Unnamed: 4'])

# %%
df.head
# Out:
# <bound method NDFrame.head of         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will �_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]>

# %%
#renaming the columns
df = df.rename(columns = {'v1' : 'target','v2' : 'text'})

# %%
df.sample(5)
# Out:
#      target                                               text
# 1470    ham              Take some small dose tablet for fever
# 626     ham  How many licks does it take to get to the cent...
# 1596   spam  As a Registered Subscriber yr draw 4 a �100 gi...
# 3790   spam  Twinks, bears, scallies, skins and jocks are c...
# 3439    ham                     What time you thinkin of goin?

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#checking for missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#checking and removing for duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# #2.EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2170452aba0>,
# ...
#  [Text(-1.014499732282844, 0.4251944181172162, 'ham'),
#   Text(1.0144998708287172, -0.42519408755122207, 'spam')],
#  [Text(-0.5533634903360967, 0.2319242280639361, '87.37'),
#   Text(0.553363565906573, -0.231924047755212, '12.63')])

# %%
# Data is imbalanced
# !pip install nltk
import nltk
nltk.download('punkt_tab')
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#number of characters
df['num_characters'] = df['text'].apply(len)

# %%
df.sample(5)
# Out:
#       target                                               text  \
# 4929       1  Hi, the SEXYCHAT girls are waiting for you to ...
# 2627       0  I know I'm lacking on most of this particular ...
# 4004       0  , ow u dey.i paid 60,400thousad.i told  u woul...
# 4355       0     Great. So should i send you my account number.
# 12         1  URGENT! You have won a 1 week FREE membership ...
#
#       num_characters
# 4929             124
# 2627             115
# 4004              55
# 4355              46
# 12               155

# %%
#number of words
df['num_words'] = df['text'].apply(lambda x:len( nltk.word_tokenize(x)))

# %%
df.sample(5)
# Out:
#       target                                               text  \
# 4789       0  Yup. Izzit still raining heavily cos i'm in e ...
# 2554       0                    I'll reach in ard 20 mins ok...
# 3520       0  Hey... are you going to quit soon? Xuhui and i...
# 1772       0  Good afternoon sexy buns! How goes the job sea...
# 187        1  Please call our customer service representativ...
#
#       num_characters  num_words
# 4789              68         18
# 2554              31          9
# 3520              77         18
# 1772             156         37
# 187              147         25

# %%
#number of sentences
df['num_sentences'] = df['text'].apply(lambda x:len( nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.923776    18.456761       1.966531
# std         58.174846    13.325633       1.449833
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#ham
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.456820    17.123782       1.820195
# std         56.356802    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#spam
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.479326   27.675345       2.978560
# std         30.014336    7.011513       1.493185
# min         13.000000    2.000000       1.000000
# 25%        131.000000   25.000000       2.000000
# 50%        148.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        223.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color ='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color ='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %% [markdown]
# ## 3.Data Preprocessing

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
import string
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
transform_text('Hi you are %* ? 20 detection backspacing')
# Out:
# 'hi 20 detect backspac'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
wc_spam = wc.generate(df[df['target']== 1]['transformed_text'].str.cat(sep =" "))

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc_spam)

# %%
wc_ham = wc.generate(df[df['target']== 0]['transformed_text'].str.cat(sep =" "))

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc_ham)

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for words in msg.split():
        spam_corpus.append(words)

# %%
len(spam_corpus)
# Out:
# 9941

# %%
from collections import Counter
sns.barplot(x=pd.DataFrame(Counter(spam_corpus).most_common(30))[0],y=pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# #### 4. MODEL BUILDING

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8713733075435203
# [[788 108]
#  [ 25 113]]
# 0.5113122171945701

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.971953578336557
# [[896   0]
#  [ 29 109]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
# tfidf --> mnb

# %%
import pickle 
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
